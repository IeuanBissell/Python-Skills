# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # TASK 1.1

# %%
x = 345
y = (2*x)+(5**3)
print(y)
# Out:
# 815

# %%
print("Hello World")
# Out:
# Hello World

# %%
w = 2
b = 5**3

# %%
def func_wxb():
    print(w*x+b)

# %%
func_wxb()
# Out:
# 815

# %% [markdown]
# # TASK 1.2

# %%
my_list = ["one","two","three","four","five"]

# %%
print("Reversed List:",my_list[::-1])
# Out:
# Reversed List: ['five', 'four', 'three', 'two', 'one']

# %%
def equals_100(x):
    if x == 100:
        return True
    else:
        return False

# %%
equals_100(99)
# Out:
# False

# %%
equals_100(100)
# Out:
# True

# %%
my_dictionary = {'data_name' : ["Animal Counts"],
                 'label' : ["cat","dog","fish"],
                 'count' : [2,5,10]}

# %%
x=my_dictionary.get("count")
print(x)
# Out:
# [2, 5, 10]

# %%
name = my_dictionary.get("label")[1]
count = my_dictionary.get("count")[1]

print(f"Animal name: {name}, count: {count}")
# Out:
# Animal name: dog, count: 5

# %% [markdown]
# # TASK 1.3

# %%
arrOne = np.random.randint(0,10, (2,3))
arrTwo = np.random.randint(0,10, (3,4))

# %%
arr_result = np.matmul(arrOne, arrTwo)
print(f"Matrix product of arrOne and arrTwo is:\n{arr_result}")
# Out:
# Matrix product of arrOne and arrTwo is:
# [[160  89  23  82]
#  [ 31  24   4  23]]

# %%
print(arr_result[:,0])
# Out:
# [160  31]

# %% [markdown]
# # Task 1.4

# %%
iris = np.load('Iris_data.npy')
print(iris.shape)
# Out:
# (150, 4)

# %%
x = iris[:,0]
y = iris[:,1]

# %%
plt.scatter(x,y)
plt.title("Iris Data Set comparing sepal length against sepal width")
plt.xlabel("Sepal Length (Cm)")
plt.ylabel("Sepal Width (Cm)")
plt.show()
